# %% [markdown]
# У завданнях 1-4. Вам наданий простий код на Python, який не відповідає вказівкам PEP8. Ваше завдання — відредагувати код так, аби він відповідав PEP8. Напишіть після редагуванню коду, дотримання яких правил з pep8 ви досягли в відредагованій версі, наприклад
# ```
# - додала пробіли навколо бінарного оператора
# - додала два порожні рядки між визначеннями функцій
# і тд
# ```
# Також можна зазанчити використані правила коментарями по коду, а не окремим повідомленням.
#
# Відредагований код має виконувати весь той самий функціонал, але бути написаний відповідно до вимог до гарного коду на Python! Не забудьте запустити відредагований код, він має бути робочим.

# %% [markdown]
# Завдання 1.

# %%
def greet(name):print(f"Hello, {name}")
def add(n1,n2):return n1+n2

x = 5;y = 3
display(greet("John"),add(x,y))
# Out:
# Hello, John
# None
# 8

# %%
def greet(name):
    return f"Hello, {name}"


def add(n1, n2):
    return n1 + n2



x = 5
y = 3


print(greet("John"))
print(add(x, y))

# зробила вигляд функцій більш читабельним
# зробила вивід результатів через print
# Out:
# Hello, John
# 8

# %% [markdown]
# Завдання 2.

# %%
from math import *
def calcArea(r):return pi*r**2
def calcCircumference(r):return 2*pi*r

radius=5
print("Area:",calcArea(radius),"Circumference:",calcCircumference(radius))
# Out:
# Area: 78.53981633974483 Circumference: 31.41592653589793

# %%
import math


def calc_area(radius):
    return math.pi * radius ** 2


def calc_circumference(radius):
    return 2 * math.pi * radius


radius = 5

print(
    "Area:", calc_area(radius),
    "\nCircumference:", calc_circumference(radius)
)

# прибрала зірочку з імпорту
# змінила назви функцій зі снейккейсу на нижні підкреслення
# змінила не зовсім зрозуміле r на повну назву (radius)
# вставила пробіли навколо операторів, розділила кожну функцію на два рядки і
# додала простір між самими функціями для кращої читабельності
# розділила вивід результату на два рядки
# Out:
# Area: 78.53981633974483
# Circumference: 31.41592653589793

# %% [markdown]
# Завдання 3.

# %%
class animal: pass
class dog(animal):
    def __init__(self,name):
        self.name=name
        self.type='Dog'

# %%
class Animal:
    pass


class Dog(Animal):

    def __init__(self, name):
        self.name = name
        self.type = "Dog"

# змінила назви класів з animal, dog на Animal, Dog
# додала два порожні рядки між визначеннями класів,
# пробіл після коми в параметрах __init__(self, name),
# пробіли навколо оператора присвоєння (self.name = name)

# %% [markdown]
# Завдання 4.

# %%
list=[1,2,3,4,5]
for i in range(len(list)):print(list[i])
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
numbers = [1, 2, 3, 4, 5]

for number in numbers:
    print(number)


# змінила назву на numbers
# додала пробіли після ком у списку
# розділила цикл і print на окремі рядки
# написала ітерацію напряму по списку замість range(len(...))
# використала більш змістовні назви змінних (number замість i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# 5.У вас є DataFrame df, що представляє результати тестів студентів з математики, англійської мови та історії. Поточний код обчислює середній бал для кожного студента шляхом ітерації за рядками DataFrame за допомогою iterrows().
#
# Ваше завдання полягає в тому, щоб змінити код так, аби уникнути використання iterrows() і замість цього застосувати більш ефективне та читабельне рішення відповідно до правил, озвучених у лекції. Рефакторинг треба зробити лише частині, де рахуються середні, імпорт і визначення датафрейму лишаємо без змін.

# %%
import pandas as pd

df = pd.DataFrame({
    'student': ['Alice', 'Bob', 'Charlie', 'David'],
    'math_score': [89, 94, 77, 85],
    'english_score': [92, 88, 79, 85],
    'history_score': [84, 92, 81, 89]
})

# %%
averages = []
for _, row in df.iterrows():
    averages.append((row['math_score'] + row['english_score'] + row['history_score']) / 3)

df['average_score'] = averages

# %%
df["average_score"] = df[
    ["math_score", "english_score", "history_score"]
].mean(axis=1)


# використано векторизовану операцію pandas, а не ітерацію по рядках
# не використовується iterrows()
# код став коротшим, швидшим, більш читабельним
# використано .mean(axis=1) для обчислення середнього значення по рядках
# немає створення проміжного списку averages

# %% [markdown]
# 6.У Вас є великий DataFrame df, що представляє транзакції продажу в магазині. Цей DataFrame містить понад 1 мільйон рядків і кілька стовпців, зокрема «product_name», «product_category», «product_price» і «transaction_date».
#
# І «product_name», і «product_category» є рядками, що представляють численні, але обмежені унікальні назви продуктів і категорії відповідно.
#
# Напишіть код для ефективного перетворення стовпців «product_name» і «product_category» на категорійний тип для ефективного використання пам’яті.
# Спробуйте вирішити це завдання, мінімізуючи використання пам'яті та зберігаючи читабельність коду. Крім того, виміряйте використання пам’яті до та після перетворення, щоб продемонструвати підвищення ефективності.
#
# Порівняйте кількість памʼяті, яку займає наданий набір даних і новий, створений Вами. В лекції був приклад. В скільки разів менше памʼяті займає новий датафрейм?

# %%
import pandas as pd
import numpy as np

np.random.seed(0)

products = ['apple', 'banana', 'cherry', 'dates', 'elderberry']
categories = ['fruit', 'fruit', 'fruit', 'fruit', 'fruit']

N_ROWS = 10**6
df = pd.DataFrame({
    'product_name': np.random.choice(products, N_ROWS),
    'product_category': np.random.choice(categories, N_ROWS),
    'product_price': np.random.uniform(1, 10, N_ROWS),
    'transaction_date': pd.date_range(start='1/1/2000', periods=N_ROWS, freq='h')
})

# %%
# вимірюємо використання пам'яті до оптимізації
memory_before = df.memory_usage(deep=True).sum()

# перетворюємо на категоріальний тип
df["product_name"] = df["product_name"].astype("category")
df["product_category"] = df["product_category"].astype("category")

# вимірюємо використання пам'яті після оптимізації
memory_after = df.memory_usage(deep=True).sum()

# виводимо результати
print(f"використання пам'яті до оптимізації: {memory_before / 1024**2:.2f} MB")
print(f"використання пам'яті після оптимізації: {memory_after / 1024**2:.2f} MB")
print(f"обсяг використаної пам'яті зменшився в: {memory_before / memory_after:.2f} разів")

# у цьому конкретному датасеті основну памʼять займають числові колонки, а не текстові,
# тому її загальний обсяг майже не змінився
# Out:
# використання пам'яті до оптимізації: 17.17 MB
# використання пам'яті після оптимізації: 17.17 MB
# обсяг використаної пам'яті зменшився в: 1.00 разів

# %% [markdown]
# 7.В цьому завданні кілька пунктів. Треба виконати усі послідовно.
#     7.1. Завантажте дані у pandas dataframe з файла `ecommerce_data.csv`. Обовʼязково при завантаженні вкажіть параметр `encoding = 'ISO-8859-1'`, без нього буде помилка.
#     7.2. Заповніть пропущені значення в колонці CustomerID на -1 та перетворіть тип цієї колонки на str, адже зараз вона типу float, а це не правильний тип даних для ідентифікатора клієнта.
#     7.3. З допомогою бібліотеки sweetviz побудуйте html звіт, який порівнює дані для країни "Germany" і країни "France". У Вас можуть виникнути багато попереджень (Warning), їх рекомендую вимкнути наступним шматком коду
#
#
#     import warnings
#
#     with warnings.catch_warnings(record=True):
#         # your code
#
#
#    7.4.Напишіть 5 відмінностей для двох зазначених країн на основі побудованого звіту, без виконання додаткового аналізу іншими інструментами.

# %%
from google.colab import files
uploaded = files.upload()
df = pd.read_csv('ecommerce_data.csv', sep=None, engine='python', encoding = 'ISO-8859-1')
# Out:
#      <input type="file" id="files-a7fb2b9d-13f1-4bc2-a2c6-2f0a4e35b90c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a7fb2b9d-13f1-4bc2-a2c6-2f0a4e35b90c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice  CustomerID         Country
# 0  12/1/2010 8:26       2.55     17850.0  United Kingdom
# 1  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 2  12/1/2010 8:26       2.75     17850.0  United Kingdom
# 3  12/1/2010 8:26       3.39     17850.0  United Kingdom
# 4  12/1/2010 8:26       3.39     17850.0  United Kingdom

# %%
df["CustomerID"] = (
    pd.to_numeric(df["CustomerID"], errors="coerce")
    .fillna(-1)
    .astype("Int64")
    .astype("string")
)

# %%
df.head(5)
# Out:
#   InvoiceNo StockCode                          Description  Quantity  \
# 0    536365    85123A   WHITE HANGING HEART T-LIGHT HOLDER         6
# 1    536365     71053                  WHITE METAL LANTERN         6
# 2    536365    84406B       CREAM CUPID HEARTS COAT HANGER         8
# 3    536365    84029G  KNITTED UNION FLAG HOT WATER BOTTLE         6
# 4    536365    84029E       RED WOOLLY HOTTIE WHITE HEART.         6
#
#       InvoiceDate  UnitPrice CustomerID         Country
# 0  12/1/2010 8:26       2.55      17850  United Kingdom
# 1  12/1/2010 8:26       3.39      17850  United Kingdom
# 2  12/1/2010 8:26       2.75      17850  United Kingdom
# 3  12/1/2010 8:26       3.39      17850  United Kingdom
# 4  12/1/2010 8:26       3.39      17850  United Kingdom

# %%
pip install sweetviz
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.1/15.1 MB 74.6 MB/s eta 0:00:00
# ...

# %%
import numpy as np
np.VisibleDeprecationWarning = DeprecationWarning

import sweetviz as sv

import warnings

# Фільтруємо дані по країнах
df_germany = df[df["Country"] == "Germany"]
df_france = df[df["Country"] == "France"]

# Вимикаємо warnings
with warnings.catch_warnings(record=True):
    report = sv.compare(
        [df_germany, "Germany"],
        [df_france, "France"]
    )

report.show_html("germany_vs_france_report.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report germany_vs_france_report.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.

# %% [markdown]
# ![4.jpg](data:image/jpeg;base64,...)

# %%
# 1. кількість транзакцій (ROWS)
# Німеччина має більший обсяг даних у цьому наборі. у звіті зафіксовано 9495 рядків для Німеччини проти 8557 рядків для Франції

# 2. Максимальна кількість товару (Quantity MAX)
# попри меншу кількість замовлень загалом, у Франції зафіксовано вищий піковий показник в одному рядку
# максимальна кількість (MAX) для Франції становить 912 одиниць, тоді як для Німеччини цей показник дорівнює 600

# 3. розмах значень у кількості (Quantity RANGE)
# діапазон значень (RANGE) у графі «Quantity» суттєво відрізняється:
# У Франції розмах становить 1162.
# У Німеччини розмах менший — 888.
# це свідчить про більшу варіативність обсягів замовлень у французькому датасеті

# 4. Унікальні номери рахунків (InvoiceNo DISTINCT)
# Німеччина демонструє вищу різноманітність замовлень
# показник унікальних значень (DISTINCT) для номерів інвойсів у Німеччини становить 603 (6% від усіх рядків),
# тоді як у Франції — 461 (5%)

# 5. коефіцієнт ексцесу (Quantity KURT.)
# Показник KURT. (Kurtosis), який описує наявність викидів, у Франції значно вищий — 454 проти 209 у Німеччини
# це вказує на те, що у даних по Франції аномально великі замовлення (викиди) трапляються частіше або вони є більш вираженими

# хоча Німеччина має більше рядків, сумарна кількість замовлених товарів (SUM) у них майже однакова: 117k для Німеччини та 110k для Франції

# %% [markdown]
# 8.З допомогою ChatGPT виявіть, чи є та які помилки в наступному коді.
# Попросіть після цього переписати код із дотриманням PEP8. Проаналізуйте результат. Чи справді ChatGPT виправив всі стилістичні помилки? Якщо ні, напишіть йому ще кілька запитів, аби код відповідав вимогам PEP8.
# Вставте фінальну версію коду з чату у ноутбук та запустіть на заданому списку. Має вертатись 50.
# Напишіть, які промпти (інструкції) при зверненні до ChatGPT ви застосували та додайте скріншот(-и) з промптами та відповідями чата.
# Якщо зробили висновки при виконанні цього завдання, то діліться також :)
#
# **ЯК ВСТАВИТИ СКРІНШОТ в Jupyter Notebook** :
# 1. Створіть нову Markdown клітинку
# 2. В новоствореній клітинці обираєте в меню Jupyter Notebook Edit -> Insert Image
# 3. Обираєте картинку
# 4. В клітинці має зʼявитись текст, який містить картинку. Запустіть клітинку.
#
# Або можна просто перетягнути картинку в Markdown клітинку.

# %%
def CalculateVariance(nl):
    sum_list = 0
    for n in nl:
        sum_list = sum_list + n
    mean = sum_list / len(nl)
    sum_squares = 0
    for n in nl:
        sum_squares = sum_squares + n**2
    mean_squares = sum_squares / len(nl)
    return mean_squares

# %%
input_list = [75, 80, 85, 90, 95]

# %%
# чат видав мені одразу кілька версій. нижче вставляю першу версію та другу, більш чисту:

# %%
# версія 1

def calculate_variance(numbers):
    """
    Calculate population variance of a list of numbers.
    """
    if len(numbers) == 0:
        raise ValueError("The list must not be empty.")

    mean = sum(numbers) / len(numbers)

    mean_squares = sum(n ** 2 for n in numbers) / len(numbers)

    variance = mean_squares - mean ** 2

    return variance

# %%
input_list = [75, 80, 85, 90, 95]

result = calculate_variance(input_list)

print(result)
# Out:
# 50.0

# %%
# версія 2

def calculate_variance(numbers):
    """
    Calculate population variance of a list of numbers.
    """
    if not numbers:
        raise ValueError("The list must not be empty.")

    mean = sum(numbers) / len(numbers)

    return sum((n - mean) ** 2 for n in numbers) / len(numbers)

# %%
input_list = [75, 80, 85, 90, 95]

result = calculate_variance(input_list)

print(result)
# Out:
# 50.0

# %% [markdown]
# ![1.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![2.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![3.jpg](data:image/jpeg;base64,...)

# %%
# чат з першого промпту виявив помилки та написав гарний код, який видає правильний результат (50)
# окрім того, навіть видав два варіанти виправленого коду, з більш чистою версією
