# %% [markdown]
# #Домашнє завдання до тем apply(), groupby(), pivot_table()

# %% [markdown]
# В цьому домашньому завданні продовжуємо працювати з набором даних `supermarket_sales.csv`.

# %% [markdown]
# 0. Імпортуйте бібліотеку pandas та зчитайте дані у змінну `df` типу `pandas.DataFrame`.

# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-993f27a1-85ee-465a-94b3-bd9856949f64" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-993f27a1-85ee-465a-94b3-bd9856949f64">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
data_path = 'supermarket_sales.csv'
df = pd.read_csv(data_path)

# %% [markdown]
# 1. Дослідимо, який філіал супермаркету ('Branch') є найприбутковішим. Для цього знайдіть сумарний прибуток за кожним філіалом і виявіть, який філіал має найвищий.

# %%
profit = df.groupby('Branch')['gross income'].sum()

# %%
print(profit)
# Out:
# Branch
# A    5057.1605
# B    5057.0320
# C    5265.1765
# Name: gross income, dtype: float64

# %%
best_branch = profit.idxmax()
best_profit = profit.max()

print(f"Найприбутковіший філіал: {best_branch} (прибуток = {best_profit:.2f})")
# Out:
# Найприбутковіший філіал: C (прибуток = 5265.18)

# %% [markdown]
# 2. В якому місті знайходиться філіал з найвищим прибутком? Може в тому місці нам розмітисти ще один магазин.
# Знайдіть відповідь за допомогою функціоналу Pandas.

# %%
best_branch = df.groupby('Branch')['gross income'].sum().idxmax()

# %%
best_city = df.loc[df['Branch'] == best_branch, 'City'].unique()[0]

# %%
print(f"Найприбутковіший філіал: {best_branch}")
print(f"Він знаходиться у місті: {best_city}")
# Out:
# Найприбутковіший філіал: C
# Він знаходиться у місті: Naypyitaw

# %% [markdown]
# 3.1. Створіть зводну таблицю, яка покаже, скільки покупок (інвойсів) було зроблено в кожній з філій (`Branch`) за різними категоріями товарів. Запишіть таблицю в змінну `invoices_by_category` і виведіть змінну на екран.
# Ця таблиця допоможе проаналізувати, в якій філії купують найбільше товарів кожної з категорій.

# %%
pd.set_option('display.width', 200)
pd.set_option('display.max_columns', 10)
invoices_by_category = df.pivot_table (index='Branch',
 columns='Product line',
 values='Invoice ID',
 aggfunc='count',
 fill_value=0)
print(invoices_by_category)
# Out:
# Product line  Electronic accessories  Fashion accessories  Food and beverages  Health and beauty  Home and lifestyle  Sports and travel
# Branch
# A                                 60                   51                  58                 47                  65                 59
# B                                 55                   62                  50                 53                  50                 62
# C                                 55                   65                  66                 52                  45                 45

# %% [markdown]
# Очікуваний результат:

# %% [markdown]
# ![](https://drive.google.com/uc?export=view&id=1rueAdko6S3UxIHGtojetTxlES-EyM6Yb)

# %% [markdown]
# 3.2. Викристовуючи змінну `invoices_by_category` дайте відповідь програмно (тобто значення треба не просто знайти очима, а вивести за допомогою коду), в якому філіалі магазину (`Branch`) найбільше інвойсів із покупкою товарів категорії "Електронні аксесуари" (`Electronic accessories`)?

# %%
best_branch_el = invoices_by_category['Electronic accessories'].idxmax()
biggest_amount_invoices = invoices_by_category['Electronic accessories'].max()
print(f'best branch: {best_branch_el}, amount of invoices: {biggest_amount_invoices}')
# Out:
# best branch: A, amount of invoices: 60

# %% [markdown]
# 4-6. **Творче завдання на розвиток аналітичного мислення**
#
# Крок 1. Сформулюйте ТРИ питання (гіпотези) до наявних даних, які допомогли б вам зрозуміти, які користувачі що, де та коли найбільше/найменше купують, аби дати на основі цих гіпотез рекомендації бізнесу. Звісно питання мають бути не тими, на які ми вже відповіли в завданнях модулю.
#
# Крок 2. Знайдіть відповіді на свої питання з допомогою функціоналу pandas.
#
# Крок 3. Напишіть, як відповідь на це питання може бути використана для прийняття бізнес рішень.
#
#  Питання можуть бути будь-якої складності, але їх має бути 3. Кожне питання оцінюється як 1 завдання. Без виконання цього завдання ДЗ не приймається. Якщо є питання щодо виконання - пишіть у чат 🙌

# %%
# 1: в якому місті середній дохід з однієї покупки найбільший?
# 2: у кого більший середній чек - у чоловіків чи у жінок?
# 3: якою категорією товарів покупці найбільше задоволені?

# %%
# 1

avg_income_one_invoice = df.groupby('City')['Total'].mean().sort_values(ascending=False)
print(avg_income_one_invoice)
# Out:
# City
# Naypyitaw    337.099715
# Mandalay     319.872506
# Yangon       312.354031
# Name: Total, dtype: float64

# %%
# допоможе зрозуміти, де клієнти витрачають найбільше, і чи варто розширювати
# присутність бізнесу саме там (наприклад, відкрити додаткову філію в Naypyitaw)

# %%
# 2

avg_check = df.groupby('Gender')['Total'].mean().sort_values(ascending=False)
print(avg_check)
# Out:
# Gender
# Female    335.095659
# Male      310.789226
# Name: Total, dtype: float64

# %%
# може показати, на кого треба ефективніше спрямовувати маркетинг певних категорій товарів
# наприклад, спеціальні пропозиції чи бонуси

# %%
# 3

best_product_line = df.groupby('Product line')['Rating'].mean().sort_values(ascending=False)
print(best_product_line)
# Out:
# Product line
# Food and beverages        7.113218
# Fashion accessories       7.029213
# Health and beauty         7.003289
# Electronic accessories    6.924706
# Sports and travel         6.916265
# Home and lifestyle        6.837500
# Name: Rating, dtype: float64

# %%
# допоможе зрозуміти, який товар просувати/розширювати асортимент
# наприклад, збільшити асортимент товарів у категорії 'Food and beverages', виділити її у вітринах або на сайті
# також можна проаналізувати можливі проблеми з категорією "Home and lifestyle", оскільки в неї найгірший рейтинг
